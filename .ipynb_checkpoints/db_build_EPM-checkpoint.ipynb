# %%
from bs4 import BeautifulSoup
from splinter import Browser
import pymongo
import pandas as pd
import requests
from sqlalchemy import create_engine

# %%
executable_path = {'executable_path': '/Applications/chromedriver'}
browser = Browser('chrome', **executable_path, headless=False)

# %%
t92 = "https://es.wikipedia.org/wiki/Premier_League_1992-93"
s92 = pd.read_html(t92)
df92=s92[4]
df92=df92[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Puntos']].copy()
df92.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df92['Season'] = "1992-93"
df92['Standing'] = df92.index + 1
df92=df92.set_index('Team')
print(df92.info())
df92
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, Manchester United to Nottingham Forest
# Data columns (total 10 columns):
# GP          22 non-null int64
# W           22 non-null int64
# L           22 non-null int64
# D           22 non-null int64
# GF          22 non-null int64
# GA          22 non-null int64
# Dif         22 non-null int64
# P           22 non-null int64
# Season      22 non-null object
# Standing    22 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.9+ KB
# None
#                      GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester United    42  24  12   6  67  31   36  84  1992-93         1
# Aston Villa          42  21  11  10  57  40   17  74  1992-93         2
# Norwich City         42  21   9  12  61  65   -4  72  1992-93         3
# Blackburn Rovers     42  20  11  11  68  46   22  71  1992-93         4
# Queens Park Rangers  42  17  12  13  63  55    8  63  1992-93         5
# ...

# %%
t93 = "https://es.wikipedia.org/wiki/Premier_League_1993-94"
s93 = pd.read_html(t93)
df93=s93[3]
df93=df93[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Puntos']].copy()
df93.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df93.at[0,'Team']="Macnhester United" 
df93['Season'] = "1993-94"
df93['Standing'] = df93.index + 1
df93=df93.set_index('Team')
print(df93.info())
df93
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, Macnhester United to Swindon Town
# Data columns (total 10 columns):
# GP          22 non-null int64
# W           22 non-null int64
# L           22 non-null int64
# D           22 non-null int64
# GF          22 non-null int64
# GA          22 non-null int64
# Dif         22 non-null int64
# P           22 non-null int64
# Season      22 non-null object
# Standing    22 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.9+ KB
# None
#                      GP   W   L   D  GF   GA  Dif   P   Season  Standing
# Team
# Macnhester United    42  27  11   4  80   38   42  92  1993-94         1
# Blackburn Rovers     42  25   9   8  63   36   27  84  1993-94         2
# Newcastle United     42  23   8  11  82   41   41  77  1993-94         3
# Arsenal              42  18  17   7  53   28   25  71  1993-94         4
# Leeds United         42  18  16   8  65   39   26  70  1993-94         5
# ...

# %%
t94 = "https://es.wikipedia.org/wiki/Premier_League_1994-95"
s94 = pd.read_html(t94)
df94=s94[2]
df94['Diferencia'] = df94['GF'] - df94['GC']
df94=df94[['Equipo', 'PJ','G', 'E','P','GF', 'GC', 'Diferencia','Pts.']].copy()
df94.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df94.at[0,'Team']="Blackburn Rovers" 
df94.at[14,'Team']="Everton" 
df94['Season'] = "1994-95"
df94['Standing'] = df94.index + 1
df94=df94.set_index('Team')
print(df94.info())
df94
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 22 entries, Blackburn Rovers to Ipswich Town
# Data columns (total 10 columns):
# GP          22 non-null int64
# W           22 non-null int64
# L           22 non-null int64
# D           22 non-null int64
# GF          22 non-null int64
# GA          22 non-null int64
# Dif         22 non-null int64
# P           22 non-null int64
# Season      22 non-null object
# Standing    22 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.9+ KB
# None
#                      GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Blackburn Rovers     42  27   8   7  80  39   41  89  1994-95         1
# Manchester United    42  26  10   6  77  28   49  88  1994-95         2
# Nottingham Forest    42  22  11   9  72  49   23  77  1994-95         3
# Liverpool            42  21  11  10  65  37   28  74  1994-95         4
# Leeds United         42  20  13   9  59  38   21  73  1994-95         5
# ...

# %%
t95 = "https://es.wikipedia.org/wiki/Premier_League_1995-96"
s95 = pd.read_html(t95)
df95=s95[0]
df95=df95[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Puntos']].copy()
df95.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df95.at[0,'Team']="Macnhester United" 
df95['Season'] = "1995-96"
df95['Standing'] = df95.index + 1
df95=df95.set_index('Team')
print(df95.info())
df95
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Macnhester United to Bolton Wanderers
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                      GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Macnhester United    38  25   7   6  73  35   38  82  1995-96         1
# Newcastle United     38  24   6   8  66  37   29  78  1995-96         2
# Liverpool            38  20  11   7  70  34   36  71  1995-96         3
# Aston Villa          38  18   9  11  52  35   17  63  1995-96         4
# Arsenal              38  17  12   9  49  32   17  63  1995-96         5
# ...

# %%
t96 = "https://es.wikipedia.org/wiki/Premier_League_1996-97"
s96 = pd.read_html(t96)
df96=s96[2]
df96['Points'] = (3*df96['PG']) + (1*df96['PE'])
df96=df96[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Points']].copy()
df96.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df96.at[0,'Team']="Macnhester United" 
df96['Season'] = "1996-97"
df96['Standing'] = df96.index + 1
df96=df96.set_index('Team')
print(df96.info())
df96
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Macnhester United to Nottingham Forest
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                      GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Macnhester United    38  21  12   5  76  44   32  75  1996-97         1
# Newcastle United     38  19  11   8  73  40   33  68  1996-97         2
# Arsenal              38  19  11   8  62  32   30  68  1996-97         3
# Liverpool            38  19  11   8  62  37   25  68  1996-97         4
# Aston Villa          38  17  10  11  47  34   13  61  1996-97         5
# ...

# %%
t97 = "https://es.wikipedia.org/wiki/Premier_League_1997-98"
s97 = pd.read_html(t97)
df97=s97[0]
df97=df97[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Puntos']].copy()
df97.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df97.at[0,'Team']="Arsenal" 
df97.at[19,'Team']="Crystal Palace" 
df97['Season'] = "1997-98"
df97['Standing'] = df97.index + 1
df97=df97.set_index('Team')
print(df97.info())
df97
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Arsenal to Crystal Palace
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                      GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Arsenal              38  23   9   6  68  33   35  78  1997-98         1
# Manchester United    38  23   8   7  73  26   47  77  1997-98         2
# Liverpool            38  18  11   9  68  42   26  65  1997-98         3
# Chelsea              38  20   3  15  71  43   28  63  1997-98         4
# Leeds United         38  17   8  13  57  46   11  59  1997-98         5
# ...

# %%
t98 = "https://es.wikipedia.org/wiki/Premier_League_1998-99"
s98 = pd.read_html(t98)
df98=s98[0]
df98=df98[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Puntos']].copy()
df98.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df98.at[0,'Team']="Manchester United" 
df98['Season'] = "1998-99"
df98['Standing'] = df98.index + 1
df98=df98.set_index('Team')
print(df98.info())
df98
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester United to Nottingham Forest
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                      GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester United    38  22  13   3  80  37   43  79  1998-99         1
# Arsenal              38  22  12   4  59  17   42  78  1998-99         2
# Chelsea              38  20  15   3  57  30   27  75  1998-99         3
# Leeds United         38  18  13   7  62  34   28  67  1998-99         4
# West Ham United      38  16   9  13  46  53   -7  57  1998-99         5
# ...

# %%
t99 = "https://es.wikipedia.org/wiki/Premier_League_1999-2000"
s99 = pd.read_html(t99)
df99=s99[0]
df99=df99[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Puntos']].copy()
df99.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df99.at[0,'Team']="Manchester United" 
df99['Season'] = "1999-00"
df99['Standing'] = df99.index + 1
df99=df99.set_index('Team')
print(df99.info())
df99
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester United to Watford
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                      GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester United    38  28   7   3  97  45   52  91  1999-00         1
# Arsenal              38  22   7   9  73  43   30  73  1999-00         2
# Leeds United         38  21   6  11  58  43   15  69  1999-00         3
# Liverpool            38  19  10   9  51  30   21  67  1999-00         4
# Chelsea              38  18  11   9  53  34   19  65  1999-00         5
# ...

# %%
t00 = "https://es.wikipedia.org/wiki/Premier_League_2000-01"
s00 = pd.read_html(t00)
df00=s00[0]
df00['Dif.'] = df00['GF'] - df00['GC']
df00=df00[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Pts.']].copy()
df00.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df00['Season'] = "2000-01"
df00['Standing'] = df00.index + 1
df00=df00.set_index('Team')
print(df00.info())
df00
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester United to Bradford City
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                    GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester United  38  24   8   6  79  31   48  80  2000-01         1
# Arsenal            38  20  10   8  63  38   25  70  2000-01         2
# Liverpool          38  20   9   9  71  39   32  69  2000-01         3
# Leeds United       38  20   8  10  64  43   21  68  2000-01         4
# Ipswich Town       38  20   6  12  57  42   15  66  2000-01         5
# ...

# %%
t01 = "https://es.wikipedia.org/wiki/Premier_League_2001-02"
s01 = pd.read_html(t01)
df01=s01[0]
df01['Diferencia'] = df01['GF'] - df01['GC']
df01=df01[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Diferencia','Pts']].copy()
df01.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df01['Season'] = "2001-02"
df01['Standing'] = df01.index + 1
df01=df01.set_index('Team')
print(df01.info())
df01
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Arsenal to Leicester City
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                    GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Arsenal            38  26   9   3  79  36   43  87  2001-02         1
# Liverpool          38  24   8   6  67  30   37  80  2001-02         2
# Manchester United  38  24   5   9  87  45   42  77  2001-02         3
# Newcastle United   38  21   8   9  74  52   22  71  2001-02         4
# Leeds United       38  18  12   8  53  37   16  66  2001-02         5
# ...

# %%
t02 = "https://es.wikipedia.org/wiki/Premier_League_2002-03"
s02 = pd.read_html(t02)
df02=s02[7]
df02['Diferencia'] = df02['GF'] - df02['GC']
df02=df02[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Diferencia','PTS']].copy()
df02.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df02['Season'] = "2002-03"
df02['Standing'] = df02.index + 1
df02=df02.set_index('Team')
print(df02.info())
df02
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester United to Sunderland
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                       GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester United     38  25   8   5  74  34   40  83  2002-03         1
# Arsenal               38  23   9   6  85  42   43  78  2002-03         2
# Newcastle United      38  21   6  11  63  48   15  69  2002-03         3
# Chelsea               38  19  10   9  68  38   30  67  2002-03         4
# Liverpool             38  18  10  10  61  41   20  64  2002-03         5
# ...

# %%
t03 = "https://es.wikipedia.org/wiki/Premier_League_2003-04"
s03 = pd.read_html(t03)
df03=s03[6]
df03['Diferencia'] = df03['GF'] - df03['GC']
df03=df03[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Diferencia','PTS']].copy()
df03.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df03.at[0,'Team']="Arsenal" 
df03.at[17,'Team']="Leicester City"
df03.at[18,'Team']="Leeds United"
df03.at[19,'Team']="Wolverhampton Wanderers"
df03['Season'] = "2003-04"
df03['Standing'] = df03.index + 1
df03=df03.set_index('Team')
print(df03.info())
df03
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Arsenal to Wolverhampton Wanderers
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                          GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Arsenal                  38  26  12   0  73  26   47  90  2003-04         1
# Chelsea                  38  24   7   7  67  30   37  79  2003-04         2
# Manchester United        38  23   6   9  64  35   29  75  2003-04         3
# Liverpool                38  16  12  10  55  37   18  60  2003-04         4
# Newcastle United         38  13  17   8  52  40   12  56  2003-04         5
# ...

# %%
t04 = "https://es.wikipedia.org/wiki/Premier_League_2004-05"
s04 = pd.read_html(t04)
df04=s04[5]
df04['Diferencia'] = df04['GF'] - df04['GC']
df04=df04[['Equipo', 'PJ','G', 'E','P','GF', 'GC', 'Diferencia','Pts']].copy()
df04.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df04.at[0,'Team']="Chelsea" 
df04['Season'] = "2004-05"
df04['Standing'] = df04.index + 1
df04=df04.set_index('Team')
print(df04.info())
df04
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Chelsea to Southampton
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                       GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Chelsea               38  29   8   1  72  15   57  95  2004-05         1
# Arsenal               38  25   8   5  87  35   52  83  2004-05         2
# Manchester United     38  22  11   5  58  26   32  77  2004-05         3
# Everton               38  18   7  13  45  46   -1  61  2004-05         4
# Liverpool             38  17   7  14  52  41   11  58  2004-05         5
# ...

# %%
t05 = "https://es.wikipedia.org/wiki/Premier_League_2005-06"
s05 = pd.read_html(t05)
df05=s05[0]
df05=df05[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'DG','Pts']].copy()
df05.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df05['Season'] = "2005-06"
df05['Standing'] = df05.index + 1
df05=df05.set_index('Team')
print(df05.info())
df05
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Chelsea to Sunderland
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                       GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Chelsea               38  29   4   5  72  22   50  91  2005-06         1
# Manchester United     38  25   8   5  72  34   38  83  2005-06         2
# Liverpool             38  25   7   6  57  25   32  82  2005-06         3
# Arsenal               38  20   7  11  68  31   37  67  2005-06         4
# Tottenham Hotspur     38  18  11   9  53  38   15  65  2005-06         5
# ...

# %%
t06 = "https://es.wikipedia.org/wiki/Premier_League_2006-07"
s06 = pd.read_html(t06)
df06=s06[0]
df06=df06[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Puntos']].copy()
df06.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df06.at[0,'Team']="Manchester United" 
df06['Season'] = "2006-07"
df06['Standing'] = df06.index + 1
df06=df06.set_index('Team')
print(df06.info())
df06
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester United to Watford
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                    GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester United  38  28   5   5  83  27   56  89  2006-07         1
# Chelsea            38  24  11   3  64  24   40  83  2006-07         2
# Liverpool          38  20   8  10  57  27   30  68  2006-07         3
# Arsenal            38  19  11   8  63  35   28  68  2006-07         4
# Tottenham          38  17   9  12  57  54    3  60  2006-07         5
# ...

# %%
t07 = "https://es.wikipedia.org/wiki/Premier_League_2007-08"
s07 = pd.read_html(t07)
df07=s07[3]
df07=df07[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Puntos']].copy()
df07.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df07.at[0,'Team']="Manchester United" 
df07['Season'] = "2007-08"
df07['Standing'] = df07.index + 1
df07=df07.set_index('Team')
print(df07.info())
df07
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester United to Derby County
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                    GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester United  38  27   6   5  80  22   58  87  2007-08         1
# Chelsea            38  25  10   3  65  26   39  85  2007-08         2
# Arsenal            38  24  11   3  74  31   43  83  2007-08         3
# Liverpool          38  21  13   4  67  28   39  76  2007-08         4
# Everton            38  19   8  11  55  33   22  65  2007-08         5
# ...

# %%
t08 = "https://es.wikipedia.org/wiki/Premier_League_2008-09"
s08 = pd.read_html(t08)
df08=s08[5]
df08['Diferencia'] = df08['GF'] - df08['GC']
df08=df08[['Equipo', 'PJ','G', 'E','P','GF', 'GC', 'Diferencia','Pts.']].copy()
df08.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df08.at[0,'Team']="Manchester United" 
df08.at[6,'Team']="Fulham" 
df08['Season'] = "2008-09"
df08['Standing'] = df08.index + 1
df08=df08.set_index('Team')
print(df08.info())
df08
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester United to West Bromwich Albion
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                       GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester United     38  28   6   4  68  24   44  90  2008-09         1
# Liverpool             38  25  11   2  77  27   50  86  2008-09         2
# Chelsea               38  25   8   5  68  24   44  83  2008-09         3
# Arsenal               38  20  12   6  68  37   31  72  2008-09         4
# Stoke City            38  17  12   9  55  37   18  63  2008-09         5
# ...

# %%
t09 = "https://es.wikipedia.org/wiki/Premier_League_2009-10"
s09 = pd.read_html(t09)
df09=s09[6]
df09['Pts.'] = (3*df09['PG']) + (1*df09['PE'])
df09=df09[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Pts.']].copy()
df09.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df09.at[1,'Team']="Manchester United" 
df09.at[2,'Team']="Arsenal" 
df09.at[3,'Team']="Tottenham Hotspur" 
df09.at[4,'Team']="Manchester City" 
df09.at[5,'Team']="Aston Villa" 
df09.at[6,'Team']="Liverpool" 
df09.at[0,'Team']="Chelsea" 
df09.at[17,'Team']="Burnley" 
df09.at[18,'Team']="Hull City" 
df09.at[19,'Team']="Portsmouth" 
df09['Season'] = "2009-10"
df09['Standing'] = df09.index + 1
df09=df09.set_index('Team')
print(df09.info())
df09
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Chelsea to Portsmouth
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                    GP   W   L   D   GF  GA  Dif   P   Season  Standing
# Team
# Chelsea            38  27   5   6  103  32   71  86  2009-10         1
# Manchester United  38  27   4   7   86  28   58  85  2009-10         2
# Arsenal            38  23   6   9   83  41   42  75  2009-10         3
# Tottenham Hotspur  38  21   7  10   67  41   26  70  2009-10         4
# Manchester City    38  18  13   7   73  45   28  67  2009-10         5
# ...

# %%
t10 = "https://es.wikipedia.org/wiki/Premier_League_2010-11"
s10 = pd.read_html(t10)
df10=s10[8]
df10['Diferencia'] = df10['GF'] - df10['GC']
df10=df10[['Equipo', 'PJ','G', 'E','P','GF', 'GC', 'Diferencia','Pts.']].copy()
df10.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df10.at[0,'Team']="Manchester United" 
df10.at[7,'Team']="Fulham" 
df10.at[12,'Team']="Stoke City" 
df10.at[17,'Team']="Birmingham City" 
df10['Season'] = "2010-11"
df10['Standing'] = df10.index + 1
df10=df10.set_index('Team')
print(df10.info())
df10
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester United to West Ham United
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                          GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester United        38  23  11   4  78  37   41  80  2010-11         1
# Chelsea                  38  21   8   9  69  33   36  71  2010-11         2
# Manchester City          38  21   8   9  60  33   27  71  2010-11         3
# Arsenal                  38  19  11   8  72  43   29  68  2010-11         4
# Tottenham Hotspur        38  16  14   8  55  46    9  62  2010-11         5
# ...

# %%
t11 = "https://es.wikipedia.org/wiki/Premier_League_2011-12"
s11 = pd.read_html(t11)
df11=s11[9]
df11=df11[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Pts.']].copy()
df11.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df11.at[0,'Team']="Manchester City"
df11.at[5,'Team']="Chelsea"
df11.at[7,'Team']="Liverpool"
df11['Season'] = "2011-12"
df11['Standing'] = df11.index + 1
df11=df11.set_index('Team')
print(df11.info())
df11
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester City to Wolverhampton Wanderers
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                          GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester City          38  28   5   5  93  29   64  89  2011-12         1
# Manchester United        38  28   5   5  89  33   56  89  2011-12         2
# Arsenal                  38  21   7  10  74  49   25  70  2011-12         3
# Tottenham Hotspur        38  20   9   9  66  41   25  69  2011-12         4
# Newcastle United         38  19   8  11  56  51    5  65  2011-12         5
# ...

# %%
t12 = "https://es.wikipedia.org/wiki/Premier_League_2012-13"
s12 = pd.read_html(t12)
df12=s12[9]
df12['Diferencia'] = df12['GF'] - df12['GC']
df12=df12[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Diferencia','PTS']].copy()
df12.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df12.at[0,'Team']="Manchester United" 
df12.at[17,'Team']="Wigan Athletic" 
df12.at[18,'Team']="Reading" 
df12.at[19,'Team']="Queens Park Rangers" 
df12['Season'] = "2012-13"
df12['Standing'] = df12.index + 1
df12=df12.set_index('Team')
print(df12.info())
df12
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester United to Queens Park Rangers
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                       GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester United     38  28   5   5  86  43   43  89  2012-13         1
# Manchester City       38  23   9   6  66  34   32  78  2012-13         2
# Chelsea               38  22   9   7  75  39   36  75  2012-13         3
# Arsenal               38  21  10   7  72  37   35  73  2012-13         4
# Tottenham Hotspur     38  21   9   8  66  46   20  72  2012-13         5
# ...

# %%
t13 = "https://es.wikipedia.org/wiki/Premier_League_2013-14"
s13 = pd.read_html(t13)
df13=s13[9]
df13['Diferencia'] = df13['GF'] - df13['GC']
df13=df13[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Diferencia','PTS']].copy()
df13.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df13.at[0,'Team']="Manchester City" 
df13.at[17,'Team']="Norwich City" 
df13.at[18,'Team']="Fulham" 
df13.at[19,'Team']="Cardiff City" 
df13['Season'] = "2013-14"
df13['Standing'] = df13.index + 1
df13=df13.set_index('Team')
print(df13.info())
df13
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester City to Cardiff City
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                       GP   W   L   D   GF  GA  Dif   P   Season  Standing
# Team
# Manchester City       38  27   5   6  102  37   65  86  2013-14         1
# Liverpool             38  26   6   6  102  50   52  84  2013-14         2
# Chelsea               38  25   7   6   71  28   43  82  2013-14         3
# Arsenal               38  24   7   7   68  41   27  79  2013-14         4
# Everton               38  21   9   8   61  39   22  72  2013-14         5
# ...

# %%
t14 = "https://es.wikipedia.org/wiki/Premier_League_2014-15"
s14 = pd.read_html(t14)
df14=s14[9]
df14['Diferencia'] = df14['GF'] - df14['GC']
df14=df14[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Diferencia','PTS']].copy()
df14.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df14.at[0,'Team']="Chelsea" 
df14.at[17,'Team']="Hull City" 
df14.at[18,'Team']="Burnley" 
df14.at[19,'Team']="Queens Park Rangers" 
df14['Season'] = "2014-15"
df14['Standing'] = df14.index + 1
df14=df14.set_index('Team')
print(df14.info())
df14
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Chelsea to Queens Park Rangers
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                       GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Chelsea               38  26   9   3  73  32   41  87  2014-15         1
# Manchester City       38  24   7   7  83  38   45  79  2014-15         2
# Arsenal               38  22   9   7  71  36   35  75  2014-15         3
# Manchester United     38  20  10   8  62  37   25  70  2014-15         4
# Tottenham Hotspur     38  19   7  12  58  53    5  64  2014-15         5
# ...

# %%
t15 = "https://es.wikipedia.org/wiki/Premier_League_2015-16"
s15 = pd.read_html(t15)
df15=s15[9]
df15['Diferencia'] = df15['GF'] - df15['GC']
df15=df15[['Equipo', 'PJ','G', 'E','P','GF', 'GC', 'Diferencia','Pts.']].copy()
df15.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df15.at[0,'Team']="Leicester City" 
df15['Season'] = "2015-16"
df15['Standing'] = df15.index + 1
df15=df15.set_index('Team')
print(df15.info())
df15
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Leicester City to Aston Villa
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                       GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Leicester City        38  23  12   3  68  36   32  81  2015-16         1
# Arsenal               38  20  11   7  65  36   29  71  2015-16         2
# Tottenham Hotspur     38  19  13   6  69  35   34  70  2015-16         3
# Manchester City       38  19   9  10  71  41   30  66  2015-16         4
# Manchester United     38  19   9  10  49  35   14  66  2015-16         5
# ...

# %%
t16 = "https://es.wikipedia.org/wiki/Premier_League_2016-17"
s16 = pd.read_html(t16)
df16=s16[10]
df16=df16[['Equipo', 'PJ','PG', 'PE','PP','GF', 'GC', 'Dif.','Pts.']].copy()
df16.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df16.at[0,'Team']="Chelsea" 
df16.at[5,'Team']="Manchester United" 
df16.at[17,'Team']="Hull City" 
df16.at[18,'Team']="Middlesbrough" 
df16.at[19,'Team']="Sunderland" 
df16['Season'] = "2016-17"
df16['Standing'] = df16.index + 1
df16=df16.set_index('Team')
print(df16.info())
df16
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Chelsea to Sunderland
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                       GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Chelsea               38  30   3   5  85  33   52  93  2016-17         1
# Tottenham Hotspur     38  26   8   4  86  26   60  86  2016-17         2
# Manchester City       38  23   9   6  80  39   41  78  2016-17         3
# Liverpool             38  22  10   6  78  42   36  76  2016-17         4
# Arsenal               38  23   6   9  77  44   33  75  2016-17         5
# ...

# %%
t17 = "https://es.wikipedia.org/wiki/Premier_League_2017-18"
s17 = pd.read_html(t17)
df17=s17[10]
df17['Diferencia'] = df17['GF'] - df17['GC']
df17=df17[['Equipo', 'PJ','G', 'E','P','GF', 'GC', 'Diferencia','Pts.']].copy()
df17.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df17.at[0,'Team']="Manchester City" 
df17['Season'] = "2017-18"
df17['Standing'] = df17.index + 1
df17=df17.set_index('Team')
print(df17.info())
df17
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester City to West Bromwich Albion
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                         GP   W   L   D   GF  GA  Dif    P   Season  Standing
# Team
# Manchester City         38  32   4   2  106  27   79  100  2017-18         1
# Manchester United       38  25   6   7   68  28   40   81  2017-18         2
# Tottenham Hotspur       38  23   8   7   74  37   37   77  2017-18         3
# Liverpool               38  21  12   5   84  38   46   75  2017-18         4
# Chelsea                 38  21   7  10   62  38   24   70  2017-18         5
# ...

# %%
t18 = "https://es.wikipedia.org/wiki/Premier_League_2018-19"
s18 = pd.read_html(t18)
df18=s18[10]
df18['Diferencia'] = df18['GF'] - df18['GC']
df18=df18[['Equipo', 'PJ','G', 'E','P','GF', 'GC', 'Diferencia','Pts.']].copy()
df18.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df18.at[0,'Team']="Manchester City"
df18.at[5,'Team']="Manchester United"
df18.at[6,'Team']="Wolverhampton Wanderers"
df18.at[17,'Team']="Cardiff City"
df18.at[18,'Team']="Fulham"
df18.at[19,'Team']="Huddersfield Town"
df18['Season'] = "2018-19"
df18['Standing'] = df18.index + 1
df18=df18.set_index('Team')
print(df18.info())
df18
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Manchester City to Huddersfield Town
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                          GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Manchester City          38  32   2   4  95  23   72  98  2018-19         1
# Liverpool                38  30   7   1  89  22   67  97  2018-19         2
# Chelsea                  38  21   9   8  63  39   24  72  2018-19         3
# Tottenham Hotspur        38  23   2  13  67  39   28  71  2018-19         4
# Arsenal                  38  21   7  10  73  51   22  70  2018-19         5
# ...

# %%
t19 = "https://es.wikipedia.org/wiki/Premier_League_2019-20"
s19 = pd.read_html(t19)
df19=s19[10]
df19['Diferencia'] = df19['GF'] - df19['GC']
df19=df19[['Equipo', 'PJ','G', 'E','P','GF', 'GC', 'Diferencia','Pts.']].copy()
df19.columns=['Team', 'GP','W', 'L','D','GF', 'GA', 'Dif','P']
df19.at[1,'Team']="Manchester City"
df19['Season'] = "2019-20"
df19['Standing'] = df19.index + 1
df19=df19.set_index('Team')
print(df19.info())
df19
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 20 entries, Liverpool to Norwich City
# Data columns (total 10 columns):
# GP          20 non-null int64
# W           20 non-null int64
# L           20 non-null int64
# D           20 non-null int64
# GF          20 non-null int64
# GA          20 non-null int64
# Dif         20 non-null int64
# P           20 non-null int64
# Season      20 non-null object
# Standing    20 non-null int64
# dtypes: int64(9), object(1)
# memory usage: 1.7+ KB
# None
#                          GP   W   L   D  GF  GA  Dif   P   Season  Standing
# Team
# Liverpool                29  27   1   1  66  21   45  82  2019-20         1
# Manchester City          28  18   3   7  68  31   37  57  2019-20         2
# Leicester City           29  16   5   8  58  28   30  53  2019-20         3
# Chelsea                  29  14   6   9  51  39   12  48  2019-20         4
# Manchester United        29  12   9   8  44  30   14  45  2019-20         5
# ...

# %%
rds_connection_string = "postgres:2311@localhost:5432/EPL9219"
engine = create_engine(f'postgresql://{rds_connection_string}')

# %%
engine.table_names()

# %%
pd.read_sql_query('select * from s92', con=engine).head(10)

# %%
df92.to_sql(name='s92', con=engine, if_exists='append', index=True)
df93.to_sql(name='s93', con=engine, if_exists='append', index=True)
df94.to_sql(name='s94', con=engine, if_exists='append', index=True)
df95.to_sql(name='s95', con=engine, if_exists='append', index=True)
df96.to_sql(name='s96', con=engine, if_exists='append', index=True)
df97.to_sql(name='s97', con=engine, if_exists='append', index=True)
df98.to_sql(name='s98', con=engine, if_exists='append', index=True)
df99.to_sql(name='s99', con=engine, if_exists='append', index=True)
df00.to_sql(name='s00', con=engine, if_exists='append', index=True)
df01.to_sql(name='s01', con=engine, if_exists='append', index=True)
df02.to_sql(name='s02', con=engine, if_exists='append', index=True)
df03.to_sql(name='s03', con=engine, if_exists='append', index=True)
df04.to_sql(name='s04', con=engine, if_exists='append', index=True)
df05.to_sql(name='s05', con=engine, if_exists='append', index=True)
df06.to_sql(name='s06', con=engine, if_exists='append', index=True)
df07.to_sql(name='s07', con=engine, if_exists='append', index=True)
df08.to_sql(name='s08', con=engine, if_exists='append', index=True)
df09.to_sql(name='s09', con=engine, if_exists='append', index=True)
df10.to_sql(name='s10', con=engine, if_exists='append', index=True)
df11.to_sql(name='s11', con=engine, if_exists='append', index=True)
df12.to_sql(name='s12', con=engine, if_exists='append', index=True)
df13.to_sql(name='s13', con=engine, if_exists='append', index=True)
df14.to_sql(name='s14', con=engine, if_exists='append', index=True)
df15.to_sql(name='s15', con=engine, if_exists='append', index=True)
df16.to_sql(name='s16', con=engine, if_exists='append', index=True)
df17.to_sql(name='s17', con=engine, if_exists='append', index=True)
df18.to_sql(name='s18', con=engine, if_exists='append', index=True)
df19.to_sql(name='s19', con=engine, if_exists='append', index=True)

# %%
DFs = pd.concat([df92, df93, df94, df95, df96, df97, df98, df99, df00, df01, df02, df03, df04, df05, df06, df07, df08, df09, df10, df11, df12, df13, df14, df15, df16, df17, df18, df19])

# %%
DFs.head()

# %%
DFs.to_csv('All92_19.csv')

# %%
df92.to_csv('df92.csv')
